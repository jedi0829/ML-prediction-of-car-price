# %% [markdown]
# # Introduction to Data Set

# %%
import pandas as pd
cars = pd.read_csv('imports-85.data')
cars.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...    \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %% [markdown]
# From above display, we realized that there was no column names for the dataframe, therefore we need to add them to the dataframe, based on data source page at UCI ML repository.

# %%
column_names = ['symboling', 
                'normalized-losses', 
                'make', 
                'fuel-type', 
                'aspiration', 
                'num-of-doors', 
                'body-style', 
                'drive-wheels', 
                'engine-location', 
                'wheel-base', 
                'length', 
                'width', 
                'height', 
                'curb-weight', 
                'engine-type', 
                'num-of-cylinders', 
                'engine-size', 
                'fuel-system', 
                'bore', 
                'stroke', 
                'compression-ratio', 
                'horsepower', 
                'peak-rpm', 
                'city-mpg', 
                'highway-mpg', 
                'price']
cars.columns = column_names
cars.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1    hatchback          rwd           front        94.5  ...            152
# 2        sedan          fwd           front        99.8  ...            109
# 3        sedan          4wd           front        99.4  ...            136
# 4        sedan          fwd           front        99.8  ...            136
#
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
# symboling            204 non-null int64
# normalized-losses    204 non-null object
# make                 204 non-null object
# fuel-type            204 non-null object
# aspiration           204 non-null object
# num-of-doors         204 non-null object
# body-style           204 non-null object
# drive-wheels         204 non-null object
# engine-location      204 non-null object
# wheel-base           204 non-null float64
# length               204 non-null float64
# width                204 non-null float64
# height               204 non-null float64
# curb-weight          204 non-null int64
# engine-type          204 non-null object
# num-of-cylinders     204 non-null object
# engine-size          204 non-null int64
# fuel-system          204 non-null object
# bore                 204 non-null object
# stroke               204 non-null object
# ...

# %% [markdown]
# Using df.info(), we can see the data type for each column, and we first should be able to determine which columns are numeric in nature and can be used as features and which column is the target column.
#
# It is not hard to identify 'price' column should our target column.
#
# Numeric columns include columns that are float and integer, they  are:
#     wheel-base, length, width, height, curb-weight, engine-size, compression-ratio, compression-ratio, city-mpg, highway-mpg.
#
# Also, some of the Object columns can also be converted into numeric and can be used as features, such as:
#     num-of-doors, num-of-cylinders, horsepower, peak-rpm, bore, stroke.
#
# Lastly, we need to choose columns that are continuous in nature, based on information provided by UCI repository.
#
# We finalized the column features to be:
# normalized-losses, wheel-base, length, width, height, curb-weight, engine-size, compression-ratio, compression-ratio, city-mpg, highway-mpg, num-of-doors, num-of-cylinders, horsepower, peak-rpm, bore, stroke, price

# %%
final_features = ['normalized-losses', 
                  'wheel-base', 
                  'length', 
                  'width', 
                  'height', 
                  'curb-weight', 
                  'engine-size', 
                  'compression-ratio',  
                  'city-mpg', 
                  'highway-mpg', 
                  'num-of-doors', 
                  'num-of-cylinders', 
                  'horsepower', 
                  'peak-rpm', 
                  'bore', 
                  'stroke', 
                  'price']
cars_features = cars[final_features]
cars_features
# Out:
#     normalized-losses  wheel-base  length  width  height  curb-weight  \
# 0                   ?        88.6   168.8   64.1    48.8         2548
# 1                   ?        94.5   171.2   65.5    52.4         2823
# 2                 164        99.8   176.6   66.2    54.3         2337
# 3                 164        99.4   176.6   66.4    54.3         2824
# 4                   ?        99.8   177.3   66.3    53.1         2507
# 5                 158       105.8   192.7   71.4    55.7         2844
# 6                   ?       105.8   192.7   71.4    55.7         2954
# 7                 158       105.8   192.7   71.4    55.9         3086
# 8                   ?        99.5   178.2   67.9    52.0         3053
# 9                 192       101.2   176.8   64.8    54.3         2395
# 10                192       101.2   176.8   64.8    54.3         2395
# 11                188       101.2   176.8   64.8    54.3         2710
# ...

# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
cars_features = cars_features.replace('?', np.nan)
cars_features
# Out:
#     normalized-losses  wheel-base  length  width  height  curb-weight  \
# 0                 NaN        88.6   168.8   64.1    48.8         2548
# 1                 NaN        94.5   171.2   65.5    52.4         2823
# 2                 164        99.8   176.6   66.2    54.3         2337
# 3                 164        99.4   176.6   66.4    54.3         2824
# 4                 NaN        99.8   177.3   66.3    53.1         2507
# 5                 158       105.8   192.7   71.4    55.7         2844
# 6                 NaN       105.8   192.7   71.4    55.7         2954
# 7                 158       105.8   192.7   71.4    55.9         3086
# 8                 NaN        99.5   178.2   67.9    52.0         3053
# 9                 192       101.2   176.8   64.8    54.3         2395
# 10                192       101.2   176.8   64.8    54.3         2395
# 11                188       101.2   176.8   64.8    54.3         2710
# ...

# %%
cars_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 17 columns):
# normalized-losses    164 non-null object
# wheel-base           204 non-null float64
# length               204 non-null float64
# width                204 non-null float64
# height               204 non-null float64
# curb-weight          204 non-null int64
# engine-size          204 non-null int64
# compression-ratio    204 non-null float64
# city-mpg             204 non-null int64
# highway-mpg          204 non-null int64
# num-of-doors         202 non-null object
# num-of-cylinders     204 non-null object
# horsepower           202 non-null object
# peak-rpm             202 non-null object
# bore                 200 non-null object
# stroke               200 non-null object
# price                200 non-null object
# dtypes: float64(5), int64(4), object(8)
# memory usage: 27.2+ KB

# %%
convert_dict = {'one': 1, 
               'two': 2, 
               'three': 3,
               'four': 4,
               'five': 5, 
               'six': 6,
               'seven': 7,
               'eight': 8, 
               'nine': 9,
               'ten': 10, 
                'eleven': 11, 
                'twelve': 12,
               np.nan: np.nan}

def word_to_num(word):
    return convert_dict[word]

cars_features['num-of-doors'] = cars_features['num-of-doors'].apply(word_to_num)
cars_features['num-of-doors']

#cars_features.astype('float')
#cars_features
# Out:
# 0      2.0
# 1      2.0
# 2      4.0
# 3      4.0
# 4      2.0
# 5      4.0
# 6      4.0
# 7      4.0
# 8      2.0
# 9      2.0
# 10     4.0
# 11     2.0
# 12     4.0
# 13     4.0
# 14     4.0
# 15     2.0
# 16     4.0
# 17     2.0
# 18     2.0
# 19     4.0
# 20     2.0
# 21     2.0
# 22     2.0
# 23     4.0
# 24     4.0
# 25     4.0
# 26     NaN
# 27     4.0
# 28     2.0
# 29     2.0
#       ...
# 174    4.0
# 175    4.0
# 176    4.0
# 177    2.0
# 178    2.0
# 179    4.0
# 180    4.0
# 181    2.0
# 182    2.0
# 183    4.0
# 184    4.0
# 185    4.0
# 186    4.0
# 187    4.0
# 188    2.0
# 189    2.0
# 190    4.0
# 191    4.0
# 192    4.0
# 193    4.0
# 194    4.0
# 195    4.0
# 196    4.0
# 197    4.0
# 198    4.0
# 199    4.0
# 200    4.0
# 201    4.0
# 202    4.0
# 203    4.0
# Name: num-of-doors, Length: 204, dtype: float64

# %%
cars_features['num-of-cylinders'] = cars_features['num-of-cylinders'].apply(word_to_num)
cars_features['num-of-cylinders']
# Out:
# 0      4
# 1      6
# 2      4
# 3      5
# 4      5
# 5      5
# 6      5
# 7      5
# 8      5
# 9      4
# 10     4
# 11     6
# 12     6
# 13     6
# 14     6
# 15     6
# 16     6
# 17     3
# 18     4
# 19     4
# 20     4
# 21     4
# 22     4
# 23     4
# 24     4
# 25     4
# 26     4
# 27     4
# 28     4
# 29     4
#       ..
# 174    4
# 175    4
# 176    4
# 177    6
# 178    6
# 179    6
# 180    6
# 181    4
# 182    4
# 183    4
# 184    4
# 185    4
# 186    4
# 187    4
# 188    4
# 189    4
# 190    5
# 191    4
# 192    4
# 193    4
# 194    4
# 195    4
# 196    4
# 197    4
# 198    4
# 199    4
# 200    4
# 201    6
# 202    6
# 203    4
# Name: num-of-cylinders, Length: 204, dtype: int64

# %%
cars_features = cars_features.astype('float')
cars_features.isnull().sum()
# Out:
# normalized-losses    40
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-size           0
# compression-ratio     0
# city-mpg              0
# highway-mpg           0
# num-of-doors          2
# num-of-cylinders      0
# horsepower            2
# peak-rpm              2
# bore                  4
# stroke                4
# price                 4
# dtype: int64

# %%
# Remove the rows with missing prices
cars_features = cars_features.dropna(subset=['price'])
cars_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 203
# Data columns (total 17 columns):
# normalized-losses    164 non-null float64
# wheel-base           200 non-null float64
# length               200 non-null float64
# width                200 non-null float64
# height               200 non-null float64
# curb-weight          200 non-null float64
# engine-size          200 non-null float64
# compression-ratio    200 non-null float64
# city-mpg             200 non-null float64
# highway-mpg          200 non-null float64
# num-of-doors         198 non-null float64
# num-of-cylinders     200 non-null float64
# horsepower           198 non-null float64
# peak-rpm             198 non-null float64
# bore                 196 non-null float64
# stroke               196 non-null float64
# price                200 non-null float64
# dtypes: float64(17)
# memory usage: 28.1 KB

# %%
#Replace NaN value in the column with the mean of the column
cars_features['normalized-losses'] = cars_features['normalized-losses'].fillna(cars_features['normalized-losses'].mean())
cars_features['normalized-losses'].isnull().sum()
# Out:
# 0

# %%
cars_features['num-of-doors'] = cars_features['num-of-doors'].fillna(cars_features['num-of-doors'].mean())
cars_features['horsepower'] = cars_features['horsepower'].fillna(cars_features['horsepower'].mean())
cars_features['peak-rpm'] = cars_features['peak-rpm'].fillna(cars_features['peak-rpm'].mean())
cars_features['bore'] = cars_features['bore'].fillna(cars_features['bore'].mean())
cars_features['stroke'] = cars_features['stroke'].fillna(cars_features['stroke'].mean())

# %%
cars_features.isnull().sum()
# Out:
# normalized-losses    0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-size          0
# compression-ratio    0
# city-mpg             0
# highway-mpg          0
# num-of-doors         0
# num-of-cylinders     0
# horsepower           0
# peak-rpm             0
# bore                 0
# stroke               0
# price                0
# dtype: int64

# %%
cars_features.head()
# Out:
#    normalized-losses  wheel-base  length  width  height  curb-weight  \
# 0              122.0        88.6   168.8   64.1    48.8       2548.0
# 1              122.0        94.5   171.2   65.5    52.4       2823.0
# 2              164.0        99.8   176.6   66.2    54.3       2337.0
# 3              164.0        99.4   176.6   66.4    54.3       2824.0
# 4              122.0        99.8   177.3   66.3    53.1       2507.0
#
#    engine-size  compression-ratio  city-mpg  highway-mpg  num-of-doors  \
# 0        130.0                9.0      21.0         27.0           2.0
# 1        152.0                9.0      19.0         26.0           2.0
# 2        109.0               10.0      24.0         30.0           4.0
# 3        136.0                8.0      18.0         22.0           4.0
# 4        136.0                8.5      19.0         25.0           2.0
#
#    num-of-cylinders  horsepower  peak-rpm  bore  stroke    price
# ...

# %% [markdown]
# Now all the data has been cleaned, with no missing values in any columns. We will now normalize or rescale all the data into the range of 0 to 1, except for 'price' column.
#
# In order to get the range of 0 to 1, we need to use a "min-max" normalization.

# %%
#Normalize all features except for 'Price', the target column
price_column = cars_features['price']
cars_features = (cars_features - cars_features.min()) / (cars_features.max() - cars_features.min())
cars_features['price'] = price_column
cars_features.head()
# Out:
#    normalized-losses  wheel-base    length     width    height  curb-weight  \
# 0           0.298429    0.058309  0.413433  0.324786  0.083333     0.411171
# 1           0.298429    0.230321  0.449254  0.444444  0.383333     0.517843
# 2           0.518325    0.384840  0.529851  0.504274  0.541667     0.329325
# 3           0.518325    0.373178  0.529851  0.521368  0.541667     0.518231
# 4           0.298429    0.384840  0.540299  0.512821  0.441667     0.395268
#
#    engine-size  compression-ratio  city-mpg  highway-mpg  num-of-doors  \
# 0     0.260377            0.12500  0.222222     0.289474           0.0
# 1     0.343396            0.12500  0.166667     0.263158           0.0
# 2     0.181132            0.18750  0.305556     0.368421           1.0
# 3     0.283019            0.06250  0.138889     0.157895           1.0
# 4     0.283019            0.09375  0.166667     0.236842           0.0
#
#    num-of-cylinders  horsepower  peak-rpm      bore    stroke    price
# ...

# %% [markdown]
# # Univariate Model

# %% [markdown]
# Let's start with some univariate k-nearest neighbors models

# %%
#Set up a function to take in parameters including train_column, target_column, df
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
def knn_train_test(train_column, target_column, df):
    train_set = df.iloc[0: int(df.shape[0] / 2)]
    test_set = df.iloc[int(df.shape[0] / 2):]
    knn = KNeighborsRegressor()
    knn.fit(train_set[[train_column]], train_set[target_column])
    prediction = knn.predict(test_set[[train_column]])
    rmse = (mean_squared_error(test_set[target_column], prediction)) ** (0.5)
    return rmse

# %%
#put all the features in a list
cols_to_train = cars_features.columns.tolist()
cols_to_train.remove('price')
cols_to_train
# Out:
# ['normalized-losses',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-size',
#  'compression-ratio',
#  'city-mpg',
#  'highway-mpg',
#  'num-of-doors',
#  'num-of-cylinders',
#  'horsepower',
#  'peak-rpm',
#  'bore',
#  'stroke']

# %%
#loop through the list of features, and collect different rmse for each feature to train
rmse_dict = {}
for col in cols_to_train:
    rmse_dict[col] = knn_train_test(col, 'price', cars_features)
rmse_dict = pd.Series(rmse_dict)
rmse_dict.sort_values()
# Out:
# highway-mpg           3970.922933
# horsepower            4178.606478
# engine-size           4294.183195
# city-mpg              5092.868063
# curb-weight           5102.952989
# num-of-cylinders      5329.284729
# width                 7122.130847
# compression-ratio     7760.437327
# length                7953.614345
# normalized-losses     8152.626555
# stroke                9066.559377
# num-of-doors          9547.252764
# peak-rpm              9738.153272
# wheel-base           10048.153976
# height               10705.689088
# bore                 13490.742630
# dtype: float64

# %% [markdown]
# According to the result, using highway-mpg, horsepower, and engine-size columns in a univariate model will generate lowest rmse with default k value.
#
# Now, we modify the knn_train_test() function to accept different k-values as parameter within (1,3,5,7,9) range for each training feature.

# %%
#modify the function so it can loop through different K values and find rmse for each k value for each feature
def knn_train_test(train_column, target_column, df):
    np.random.seed(1)
    shuffled_index = np.random.permutation(df.index)
    rand_df = df.reindex(shuffled_index)
    train_set = rand_df.iloc[0: int(len(rand_df) / 2)]
    test_set = rand_df.iloc[int(len(rand_df) / 2):]
    k_values = [1, 3, 5, 7, 9]
    rmse_by_k = {}
    for k in k_values:
        knn = KNeighborsRegressor(n_neighbors=k)
        knn.fit(train_set[[train_column]], train_set[target_column])
        prediction = knn.predict(test_set[[train_column]])
        rmse = (mean_squared_error(test_set[target_column], prediction)) ** (0.5)
        rmse_by_k[k] = rmse
    return rmse_by_k

# %%
rmse_all = {}
for col in cols_to_train:
    rmse = knn_train_test(col, 'price', cars_features)
    rmse_all[col] = rmse
rmse_all
# Out:
# {'bore': {1: 5926.514010782393,
#   3: 5927.911351770069,
#   5: 6206.9245622933095,
#   7: 6239.1231894606235,
#   9: 6407.868283419558},
#  'city-mpg': {1: 4170.034286429789,
#   3: 3438.0091973569693,
#   5: 3813.193148373158,
#   7: 3706.737982542668,
#   9: 3811.0390099593706},
#  'compression-ratio': {1: 7344.202947903877,
#   3: 5943.417906577177,
#   5: 7193.5885991346495,
#   7: 7540.580427735179,
#   9: 7180.410828835924},
#  'curb-weight': {1: 4390.877922466076,
#   3: 3668.3589437240184,
#   5: 3439.4916393560256,
#   7: 3174.0695108639184,
#   9: 3373.692477825783},
#  'engine-size': {1: 3398.1555291069303,
#   3: 3143.6417681833063,
#   5: 3247.180990459263,
#   7: 3058.254836187008,
#   9: 3141.6475726897906},
#  'height': {1: 10910.35914761746,
#   3: 7805.349593138741,
#   5: 7380.628859304605,
#   7: 7272.536203121596,
#   9: 7121.205659190993},
#  'highway-mpg': {1: 3667.7066335790814,
#   3: 3602.7490403548477,
#   5: 3737.1620469013646,
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for k,v in rmse_all.items():
    x = list(v.keys())
    y = list(v.values())
    plt.plot(x, y)

# %% [markdown]
# # Multivariate Model

# %% [markdown]
# Now make changes to knn_train_test() function to work with multiple columns

# %%
# First, find out which features are the best features (smallest rsme)
feature_avg_rsme = {}
for k,v in rmse_all.items():
    avg_rmse = np.mean(list(v.values()))
    feature_avg_rsme[k] = avg_rmse
pd.Series(feature_avg_rsme).sort_values()
# Out:
# engine-size          3197.776139
# curb-weight          3609.298099
# city-mpg             3787.802725
# highway-mpg          3788.622765
# width                4131.406807
# horsepower           4412.960576
# wheel-base           5249.730986
# num-of-cylinders     5265.238884
# length               5537.461758
# bore                 6141.668280
# compression-ratio    7040.440142
# peak-rpm             7112.435583
# normalized-losses    7651.230485
# num-of-doors         7654.446421
# stroke               7657.690117
# height               8098.015892
# dtype: float64

# %%
#modify the training function to take in not one feature, but a list of multiple features at the same time to train
def knn_train_test(train_columns, target_column, df):
    np.random.seed(1)
    shuffled_index = np.random.permutation(df.index)
    shuffled_df = df.reindex(shuffled_index)
    train_set = shuffled_df.iloc[0: int(df.shape[0] / 2)]
    test_set = shuffled_df.iloc[int(df.shape[0] / 2):]
    k_list = [5]
    rmse_by_k = {}
    for k in k_list:
        knn = KNeighborsRegressor(n_neighbors=k)
        knn.fit(train_set[train_columns], train_set[target_column])
        prediction = knn.predict(test_set[train_columns])
        rmse = (mean_squared_error(test_set[target_column], prediction)) ** (0.5)
        rmse_by_k[k] = rmse
    return rmse_by_k

# %%
#run the training model on best two, three, four, and five features separately and collect rmse for each training
results_by_num_best_features = {}
best_2_features = ['engine-size', 'curb-weight']
results_by_num_best_features['best_2_features'] = knn_train_test(best_2_features, 'price', cars_features)

best_3_features = ['engine-size', 'curb-weight', 'city-mpg']
results_by_num_best_features['best_3_features'] = knn_train_test(best_3_features, 'price', cars_features)

best_4_features = ['engine-size', 'curb-weight', 'city-mpg', 'highway-mpg']
results_by_num_best_features['best_4_features'] = knn_train_test(best_4_features, 'price', cars_features)

best_5_features = ['engine-size', 'curb-weight', 'city-mpg', 'highway-mpg', 'width']
results_by_num_best_features['best_5_features'] = knn_train_test(best_5_features, 'price', cars_features)

results_by_num_best_features
# Out:
# {'best_2_features': {5: 2776.7887244801323},
#  'best_3_features': {5: 3007.3486027396293},
#  'best_4_features': {5: 3207.3124028694183},
#  'best_5_features': {5: 2660.144132034954}}

# %% [markdown]
# # Hyperparamter Tuning

# %% [markdown]
# Now we need to tune the hyperparameter, the k-value from 1 to 25, and plot the resulting rmse values, and find out which k-value produced the best predicting result.

# %%
#modify the training function to change the k-value list to include the range of 1 to 25
def knn_train_test(train_columns, target_column, df):
    np.random.seed(1)
    shuffled_index = np.random.permutation(df.index)
    shuffled_df = df.reindex(shuffled_index)
    train_set = shuffled_df.iloc[0: int(df.shape[0] / 2)]
    test_set = shuffled_df.iloc[int(df.shape[0] / 2):]
    k_list = list(range(1,26,1))
    rmse_by_k = {}
    for k in k_list:
        knn = KNeighborsRegressor(n_neighbors=k)
        knn.fit(train_set[train_columns], train_set[target_column])
        prediction = knn.predict(test_set[train_columns])
        rmse = (mean_squared_error(test_set[target_column], prediction)) ** (0.5)
        rmse_by_k[k] = rmse
    return rmse_by_k

# %%
#Choose the best three models to run the training, the best 2,3,5 features
results_by_num_best_features = {}
best_2_features = ['engine-size', 'curb-weight']
results_by_num_best_features['best_2_features'] = knn_train_test(best_2_features, 'price', cars_features)

best_3_features = ['engine-size', 'curb-weight', 'city-mpg']
results_by_num_best_features['best_3_features'] = knn_train_test(best_3_features, 'price', cars_features)

best_5_features = ['engine-size', 'curb-weight', 'city-mpg', 'highway-mpg', 'width']
results_by_num_best_features['best_5_features'] = knn_train_test(best_5_features, 'price', cars_features)

results_by_num_best_features
# Out:
# {'best_2_features': {1: 3405.0011057266925,
#   2: 2806.815926009399,
#   3: 2832.046659416315,
#   4: 2755.885691343166,
#   5: 2776.7887244801323,
#   6: 2845.331496943722,
#   7: 2939.963979267051,
#   8: 3090.0602294645896,
#   9: 3287.39623079902,
#   10: 3425.1888036865944,
#   11: 3584.4292620828824,
#   12: 3635.5259878023303,
#   13: 3663.6037412497835,
#   14: 3664.5333259279732,
#   15: 3681.5923927742647,
#   16: 3707.625229104499,
#   17: 3740.66261656526,
#   18: 3711.4044350521394,
#   19: 3747.9428945198347,
#   20: 3731.3753714046247,
#   21: 3721.4542332692286,
#   22: 3754.542140976416,
#   23: 3768.9635970788922,
#   24: 3805.6710862613386,
#   25: 3838.1666278221946},
#  'best_3_features': {1: 2777.6202422217475,
#   2: 2606.028364197136,
#   3: 2804.9334531618865,
#   4: 2973.8428185388348,
#   5: 3007.3486027396293,
#   6: 3164.6180440931576,
#   7: 3320.9176540989574,
#   8: 3227.3661070455346,
#   9: 3222.521540580632,
#   10: 3381.7607558637264,
# ...

# %%
# visualize the results thru plot
for k,v in results_by_num_best_features.items():
    x = list(v.keys())
    y = list(v.values())
    plt.plot(x, y)
    plt.xlabel('k value')
    plt.ylabel('RMSE')

# %% [markdown]
# From the visualization, we can see that k-value of 2 to 5 will likely generate the best prediction of car price.
